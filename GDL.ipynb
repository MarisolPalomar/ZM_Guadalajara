# %% [markdown]
# # **Guadalajara**

# %% [markdown]
# # **1. Librerías a utilizar.**

# %%
# !pip install mapclassify
# !pip install libpysal
# !pip install geopandas
# Out:
# Requirement already satisfied: mapclassify in /opt/anaconda3/lib/python3.8/site-packages (2.4.2)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from mapclassify) (1.5.0)
# Requirement already satisfied: numpy>=1.3 in /opt/anaconda3/lib/python3.8/site-packages (from mapclassify) (1.20.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.8/site-packages (from mapclassify) (0.23.1)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.8/site-packages (from mapclassify) (2.5.1)
# Requirement already satisfied: pandas>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from mapclassify) (1.2.4)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->mapclassify) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->mapclassify) (2.1.0)
# Requirement already satisfied: decorator<5,>=4.3 in /opt/anaconda3/lib/python3.8/site-packages (from networkx->mapclassify) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.0->mapclassify) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.0->mapclassify) (2020.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->mapclassify) (1.15.0)
# Requirement already satisfied: libpysal in /opt/anaconda3/lib/python3.8/site-packages (4.4.0)
# Requirement already satisfied: scipy>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from libpysal) (1.5.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.8/site-packages (from libpysal) (2.11.2)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.8/site-packages (from libpysal) (1.2.4)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from libpysal) (2.25.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.8/site-packages (from libpysal) (4.9.1)
# Requirement already satisfied: numpy>=1.3 in /opt/anaconda3/lib/python3.8/site-packages (from libpysal) (1.20.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from jinja2->libpysal) (1.1.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas->libpysal) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas->libpysal) (2.8.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->libpysal) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->libpysal) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->libpysal) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->libpysal) (2020.6.20)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->libpysal) (2.0.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->libpysal) (1.15.0)
# Requirement already satisfied: geopandas in /opt/anaconda3/lib/python3.8/site-packages (0.9.0+24.ga26bde2)
# Requirement already satisfied: fiona>=1.8 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.8.19)
# Requirement already satisfied: shapely>=1.6 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas) (3.0.1)
# Requirement already satisfied: pandas>=0.24.0 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.2.4)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.1)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: attrs>=17 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (19.3.0)
# Requirement already satisfied: click<8,>=4.0 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: munch in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2020.6.20)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (1.20.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.8/site-packages (3.4.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (7.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.20.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.15.0)

# %%
import numpy as np
import mapclassify
import pandas as pd
import libpysal as ps
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# !pip install contextily
# Out:
# Requirement already satisfied: contextily in /opt/anaconda3/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.8/site-packages (from contextily) (7.2.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from contextily) (2.25.1)
# Requirement already satisfied: mercantile in /opt/anaconda3/lib/python3.8/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.8/site-packages (from contextily) (0.16.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.8/site-packages (from contextily) (3.4.1)
# Requirement already satisfied: geopy in /opt/anaconda3/lib/python3.8/site-packages (from contextily) (2.1.0)
# Requirement already satisfied: rasterio in /opt/anaconda3/lib/python3.8/site-packages (from contextily) (1.2.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->contextily) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->contextily) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->contextily) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->contextily) (2.10)
# Requirement already satisfied: click>=3.0 in /opt/anaconda3/lib/python3.8/site-packages (from mercantile->contextily) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib->contextily) (1.20.2)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/anaconda3/lib/python3.8/site-packages (from geopy->contextily) (1.50)
# Requirement already satisfied: affine in /opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (2.3.0)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (0.7.1)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: attrs in /opt/anaconda3/lib/python3.8/site-packages (from rasterio->contextily) (19.3.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->contextily) (1.15.0)

# %%
import matplotlib.patches as mpatches
import contextily as ctx

# %% [markdown]
# # **2. Importar las bases de datos, para revisar coordenadas y los datos que contienen.**

# %%
AGEBS= gpd.read_file('/Users/edalimurillo/Desktop/Justicia Ambiental/Gravity Model/GDL/agebs_urbanas.shp')
print ('Forma de los datos:',AGEBS.shape)
AGEBS.head(5)
# Out:
# Forma de los datos: (2068, 6)
#           CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 0  1400200020219      14     002    0002     0219
# 1  1400200020045      14     002    0002     0045
# 2  1400200020172      14     002    0002     0172
# 3  1400200020261      14     002    0002     0261
# 4  1400200020149      14     002    0002     0149
#
#                                             geometry
# 0  POLYGON ((2328998.333 938286.411, 2328992.454 ...
# 1  POLYGON ((2329856.497 937938.359, 2329843.636 ...
# 2  POLYGON ((2330222.579 938052.526, 2330204.500 ...
# 3  POLYGON ((2329372.664 937326.401, 2329230.982 ...
# 4  POLYGON ((2328663.851 938014.271, 2328701.766 ...

# %%
AGEBS.crs
# Out:
# <Projected CRS: EPSG:6372>
# Name: Mexico ITRF2008 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# ##**Áreas verdes Inegi (2020)**

# %%
Area_Verde= gpd.read_file('/Users/edalimurillo/Desktop/Justicia Ambiental/Gravity Model/GDL/AreasVerdes_gdl.shp')
Area_Verde.head()
# Out:
#       CVEGEO CVE_ENT CVE_MUN CVE_LOC  CONDICION GEOGRAFICO  NOMSERV  \
# 0  140020002      14     002    0002  No Aplica   Camellón  Ninguno
# 1  140020004      14     002    0004  No Aplica   Camellón  Ninguno
# 2  140020001      14     002    0001  No Aplica   Camellón  Ninguno
# 3  140020001      14     002    0001  No Aplica   Camellón  Ninguno
# 4  140020001      14     002    0001  No Aplica   Camellón  Ninguno
#
#          TIPO  CVE_SERV  AMBITO  \
# 0  Área Verde         3  Urbana
# 1  Área Verde         1  Urbana
# 2  Área Verde         1  Urbana
# 3  Área Verde         2  Urbana
# 4  Área Verde         3  Urbana
#
#                                             geometry
# 0  POLYGON ((2329105.446 937918.412, 2329087.944 ...
# 1  POLYGON ((2332663.551 936196.597, 2332759.901 ...
# 2  POLYGON ((2334397.312 935139.204, 2334344.889 ...
# 3  POLYGON ((2335130.753 936714.573, 2335126.174 ...
# 4  POLYGON ((2334966.760 936876.256, 2334966.433 ...

# %%
Area_Verde.crs
# Out:
# <Projected CRS: EPSG:6372>
# Name: Mexico ITRF2008 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# **Datos Pobreza**

# %%
Pobreza_ageb = pd.read_csv ('/Users/edalimurillo/Desktop/Justicia Ambiental/Gravity Model/GDL/Pobreza_GDL.csv')
Pobreza_ageb.head(5)
# Out:
#    cve_ent  nom_ent  cve_mun nom_mun        cve_geo cve_ageb Rango_Pobreza  \
# 0       14  Jalisco    14001  Acatic  1400100010067     0067      (34, 50]
# 1       14  Jalisco    14001  Acatic  1400100010071     0071      (34, 50]
# 2       14  Jalisco    14001  Acatic  1400100010103     0103      (34, 50]
# 3       14  Jalisco    14001  Acatic  1400100010118     0118      (50, 70]
# 4       14  Jalisco    14001  Acatic  1400100010122     0122      (34, 50]
#
#   Rango_Pobreza_Ext
# 0          [ 0, 20]
# 1          [ 0, 20]
# 2          [ 0, 20]
# 3          [ 0, 20]
# 4          [ 0, 20]

# %% [markdown]
# #**3. Homologar bases de datos**

# %%
AGEBS= AGEBS.rename({'CVEGEO':'Clave_AGEB'}, axis=1)
Pobreza_ageb = Pobreza_ageb.rename({'cve_geo':'Clave_AGEB'}, axis=1)

# %%
Pobreza_ageb=Pobreza_ageb.dropna()

# %%
Pobreza_ageb['Min_RP'] = Pobreza_ageb.Rango_Pobreza.str.extract('(\d+)').astype(int)
Pobreza_ageb['Max_RP'] = Pobreza_ageb.Rango_Pobreza.str.extract('( \d+)').astype(int)
Pobreza_ageb['Pobreza_AV'] = ((Pobreza_ageb['Min_RP'] + Pobreza_ageb['Max_RP']) / 2)
Pobreza_ageb2 = Pobreza_ageb[['Clave_AGEB','nom_mun', 'Rango_Pobreza', 'Pobreza_AV' ]]

# %%
Pobreza_ageb2.set_index('Clave_AGEB')
AGEBS.set_index('Clave_AGEB')
# Out:
#               CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# Clave_AGEB
# 1400200020219      14     002    0002     0219
# 1400200020045      14     002    0002     0045
# 1400200020172      14     002    0002     0172
# 1400200020261      14     002    0002     0261
# 1400200020149      14     002    0002     0149
# ...               ...     ...     ...      ...
# 1412400010122      14     124    0001     0122
# 1412400010226      14     124    0001     0226
# 1412400010156      14     124    0001     0156
# 1412400940391      14     124    0094     0391
# 1412400010372      14     124    0001     0372
#
#                                                         geometry
# Clave_AGEB
# 1400200020219  POLYGON ((2328998.333 938286.411, 2328992.454 ...
# 1400200020045  POLYGON ((2329856.497 937938.359, 2329843.636 ...
# 1400200020172  POLYGON ((2330222.579 938052.526, 2330204.500 ...
# 1400200020261  POLYGON ((2329372.664 937326.401, 2329230.982 ...
# 1400200020149  POLYGON ((2328663.851 938014.271, 2328701.766 ...
# ...                                                          ...
# 1412400010122  POLYGON ((2389984.813 959214.947, 2389990.990 ...
# 1412400010226  POLYGON ((2391239.701 957658.792, 2391293.428 ...
# 1412400010156  POLYGON ((2389945.566 957216.321, 2389959.436 ...
# 1412400940391  POLYGON ((2383877.864 952898.607, 2383916.072 ...
# 1412400010372  POLYGON ((2389423.524 958620.493, 2389453.464 ...
#
# [2068 rows x 5 columns]

# %%
Pobreza_AGEB = AGEBS.merge(Pobreza_ageb2 ,left_on='Clave_AGEB', right_on='Clave_AGEB',how='left')
Pobreza_A = Pobreza_AGEB.copy()
print ('Forma de los datos:',Pobreza_AGEB.shape)
Pobreza_AGEB.head(50)
# Out:
# Forma de los datos: (2068, 9)
#        Clave_AGEB CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 0   1400200020219      14     002    0002     0219
# 1   1400200020045      14     002    0002     0045
# 2   1400200020172      14     002    0002     0172
# 3   1400200020261      14     002    0002     0261
# 4   1400200020149      14     002    0002     0149
# 5   1400200020242      14     002    0002     0242
# 6   1400200020223      14     002    0002     0223
# 7   1400200020327      14     002    0002     0327
# 8   1400200020153      14     002    0002     0153
# 9   1400200020257      14     002    0002     0257
# 10  1400200020238      14     002    0002     0238
# 11  140020002005A      14     002    0002     005A
# 12  1400200020276      14     002    0002     0276
# 13  1400200020331      14     002    0002     0331
# 14  1400200020204      14     002    0002     0204
# 15  1400200020100      14     002    0002     0100
# 16  1400200010134      14     002    0001     0134
# 17  1400200010030      14     002    0001     0030
# 18  1400200010083      14     002    0001     0083
# 19  1400200010064      14     002    0001     0064
# 20  1400200010168      14     002    0001     0168
# 21  1400200010295      14     002    0001     0295
# 22  1400200010079      14     002    0001     0079
# 23  1400200010308      14     002    0001     0308
# 24  1400200010191      14     002    0001     0191
# 25  1400200010280      14     002    0001     0280
# 26  1400200040187      14     002    0004     0187
# 27  1400200010312      14     002    0001     0312
# 28  1400200010098      14     002    0001     0098
# 29  1400200010115      14     002    0001     0115
# 30  140020001012A      14     002    0001     012A
# 31  1403900012696      14     039    0001     2696
# 32  1403900014207      14     039    0001     4207
# 33  1403900013020      14     039    0001     3020
# 34  1403900014194      14     039    0001     4194
# 35  1403900015243      14     039    0001     5243
# 36  1403900015084      14     039    0001     5084
# 37  1403900011927      14     039    0001     1927
# 38  1403900013088      14     039    0001     3088
# 39  140390001051A      14     039    0001     051A
# 40  140390001083A      14     039    0001     083A
# 41  1403900012408      14     039    0001     2408
# 42  1403900015328      14     039    0001     5328
# 43  1403900012802      14     039    0001     2802
# 44  1403900014353      14     039    0001     4353
# 45  140390001133A      14     039    0001     133A
# 46  1403900015205      14     039    0001     5205
# 47  1403900011838      14     039    0001     1838
# 48  1403900011700      14     039    0001     1700
# 49  1403900011325      14     039    0001     1325
#
#                                              geometry            nom_mun  \
# 0   POLYGON ((2328998.333 938286.411, 2328992.454 ...  Acatl�n de Ju�rez
# 1   POLYGON ((2329856.497 937938.359, 2329843.636 ...  Acatl�n de Ju�rez
# 2   POLYGON ((2330222.579 938052.526, 2330204.500 ...                NaN
# 3   POLYGON ((2329372.664 937326.401, 2329230.982 ...  Acatl�n de Ju�rez
# 4   POLYGON ((2328663.851 938014.271, 2328701.766 ...  Acatl�n de Ju�rez
# 5   POLYGON ((2329757.289 937226.525, 2329780.028 ...                NaN
# 6   POLYGON ((2329751.218 937234.063, 2329741.868 ...  Acatl�n de Ju�rez
# 7   POLYGON ((2328715.082 938542.198, 2328745.425 ...  Acatl�n de Ju�rez
# 8   POLYGON ((2329632.518 937215.672, 2329642.410 ...                NaN
# 9   POLYGON ((2329478.421 936997.567, 2329466.579 ...  Acatl�n de Ju�rez
# 10  POLYGON ((2329562.766 937004.735, 2329555.889 ...  Acatl�n de Ju�rez
# 11  POLYGON ((2330284.971 937931.529, 2330300.852 ...  Acatl�n de Ju�rez
# 12  POLYGON ((2328674.308 937938.338, 2328696.881 ...                NaN
# 13  POLYGON ((2328685.910 938036.740, 2328663.851 ...                NaN
# 14  POLYGON ((2330063.527 937174.626, 2330091.007 ...  Acatl�n de Ju�rez
# 15  POLYGON ((2329109.661 938217.440, 2329181.253 ...  Acatl�n de Ju�rez
# 16  POLYGON ((2333891.451 935360.697, 2333909.933 ...                NaN
# 17  POLYGON ((2335121.875 937099.226, 2335147.449 ...  Acatl�n de Ju�rez
# 18  POLYGON ((2335137.895 935874.006, 2335129.591 ...  Acatl�n de Ju�rez
# 19  POLYGON ((2335041.202 937131.618, 2335015.312 ...  Acatl�n de Ju�rez
# 20  POLYGON ((2333545.618 937094.537, 2333498.237 ...  Acatl�n de Ju�rez
# 21  POLYGON ((2335433.858 936001.276, 2335445.098 ...  Acatl�n de Ju�rez
# 22  POLYGON ((2334621.644 935400.958, 2334609.355 ...  Acatl�n de Ju�rez
# 23  POLYGON ((2333467.527 936565.906, 2333467.187 ...                NaN
# 24  POLYGON ((2334803.893 934583.814, 2334750.092 ...                NaN
# 25  POLYGON ((2333205.849 936903.620, 2333215.772 ...  Acatl�n de Ju�rez
# 26  POLYGON ((2333433.953 935988.527, 2333427.469 ...  Acatl�n de Ju�rez
# 27  POLYGON ((2333241.552 937191.010, 2333200.911 ...                NaN
# 28  POLYGON ((2335239.285 935824.555, 2335278.526 ...                NaN
# 29  POLYGON ((2333200.911 937199.115, 2333241.552 ...                NaN
# 30  POLYGON ((2335534.820 936248.012, 2335466.726 ...  Acatl�n de Ju�rez
# 31  POLYGON ((2357150.791 959790.056, 2357114.481 ...        Guadalajara
# 32  POLYGON ((2367389.408 966302.223, 2367366.228 ...        Guadalajara
# 33  POLYGON ((2363811.145 968828.465, 2363848.423 ...        Guadalajara
# 34  POLYGON ((2367420.611 966341.257, 2367273.896 ...        Guadalajara
# 35  POLYGON ((2368089.648 964164.191, 2368052.176 ...        Guadalajara
# 36  POLYGON ((2366581.336 962143.953, 2366700.508 ...        Guadalajara
# 37  POLYGON ((2361630.043 962476.234, 2361629.212 ...        Guadalajara
# 38  POLYGON ((2364167.127 968355.931, 2364172.475 ...        Guadalajara
# 39  POLYGON ((2365518.450 966007.163, 2365524.028 ...        Guadalajara
# 40  POLYGON ((2365133.519 964621.515, 2365040.324 ...        Guadalajara
# 41  POLYGON ((2358161.316 961045.647, 2358143.729 ...        Guadalajara
# 42  POLYGON ((2358721.889 961463.878, 2358717.259 ...        Guadalajara
# 43  POLYGON ((2358103.415 959121.736, 2358073.432 ...        Guadalajara
# 44  POLYGON ((2365360.343 961698.680, 2365359.317 ...        Guadalajara
# 45  POLYGON ((2358964.248 963828.876, 2358863.402 ...        Guadalajara
# 46  POLYGON ((2366143.019 960665.326, 2366062.546 ...        Guadalajara
# 47  POLYGON ((2358663.374 963265.851, 2358677.724 ...        Guadalajara
# 48  POLYGON ((2364686.270 962954.726, 2364702.436 ...        Guadalajara
# 49  POLYGON ((2358267.004 964307.823, 2358402.036 ...        Guadalajara
#
#    Rango_Pobreza  Pobreza_AV
# 0       (50, 70]        60.0
# 1       (18, 34]        26.0
# 2            NaN         NaN
# 3       (34, 50]        42.0
# 4       (34, 50]        42.0
# 5            NaN         NaN
# 6       (50, 70]        60.0
# 7      (70, 100]        85.0
# 8            NaN         NaN
# 9       (50, 70]        60.0
# 10      (50, 70]        60.0
# 11      (18, 34]        26.0
# 12           NaN         NaN
# 13           NaN         NaN
# 14      (34, 50]        42.0
# 15      (34, 50]        42.0
# 16           NaN         NaN
# 17      (18, 34]        26.0
# 18      (34, 50]        42.0
# 19      (18, 34]        26.0
# 20      (18, 34]        26.0
# 21      (18, 34]        26.0
# 22      (34, 50]        42.0
# 23           NaN         NaN
# 24           NaN         NaN
# 25      (34, 50]        42.0
# 26      (18, 34]        26.0
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# 30      [ 0, 18]         0.0
# 31      [ 0, 18]         0.0
# 32      (34, 50]        42.0
# 33      (34, 50]        42.0
# 34      (34, 50]        42.0
# 35      (18, 34]        26.0
# 36      (34, 50]        42.0
# 37      (18, 34]        26.0
# 38      (18, 34]        26.0
# 39      (34, 50]        42.0
# 40      [ 0, 18]         0.0
# 41      (18, 34]        26.0
# 42      [ 0, 18]         0.0
# 43      (18, 34]        26.0
# 44      (18, 34]        26.0
# 45      (18, 34]        26.0
# 46      [ 0, 18]         0.0
# 47      [ 0, 18]         0.0
# 48      (34, 50]        42.0
# 49      [ 0, 18]         0.0

# %%
Pobreza_A = Pobreza_A.fillna(0)
Pobreza_A.head(50)
# Out:
#        Clave_AGEB CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 0   1400200020219      14     002    0002     0219
# 1   1400200020045      14     002    0002     0045
# 2   1400200020172      14     002    0002     0172
# 3   1400200020261      14     002    0002     0261
# 4   1400200020149      14     002    0002     0149
# 5   1400200020242      14     002    0002     0242
# 6   1400200020223      14     002    0002     0223
# 7   1400200020327      14     002    0002     0327
# 8   1400200020153      14     002    0002     0153
# 9   1400200020257      14     002    0002     0257
# 10  1400200020238      14     002    0002     0238
# 11  140020002005A      14     002    0002     005A
# 12  1400200020276      14     002    0002     0276
# 13  1400200020331      14     002    0002     0331
# 14  1400200020204      14     002    0002     0204
# 15  1400200020100      14     002    0002     0100
# 16  1400200010134      14     002    0001     0134
# 17  1400200010030      14     002    0001     0030
# 18  1400200010083      14     002    0001     0083
# 19  1400200010064      14     002    0001     0064
# 20  1400200010168      14     002    0001     0168
# 21  1400200010295      14     002    0001     0295
# 22  1400200010079      14     002    0001     0079
# 23  1400200010308      14     002    0001     0308
# 24  1400200010191      14     002    0001     0191
# 25  1400200010280      14     002    0001     0280
# 26  1400200040187      14     002    0004     0187
# 27  1400200010312      14     002    0001     0312
# 28  1400200010098      14     002    0001     0098
# 29  1400200010115      14     002    0001     0115
# 30  140020001012A      14     002    0001     012A
# 31  1403900012696      14     039    0001     2696
# 32  1403900014207      14     039    0001     4207
# 33  1403900013020      14     039    0001     3020
# 34  1403900014194      14     039    0001     4194
# 35  1403900015243      14     039    0001     5243
# 36  1403900015084      14     039    0001     5084
# 37  1403900011927      14     039    0001     1927
# 38  1403900013088      14     039    0001     3088
# 39  140390001051A      14     039    0001     051A
# 40  140390001083A      14     039    0001     083A
# 41  1403900012408      14     039    0001     2408
# 42  1403900015328      14     039    0001     5328
# 43  1403900012802      14     039    0001     2802
# 44  1403900014353      14     039    0001     4353
# 45  140390001133A      14     039    0001     133A
# 46  1403900015205      14     039    0001     5205
# 47  1403900011838      14     039    0001     1838
# 48  1403900011700      14     039    0001     1700
# 49  1403900011325      14     039    0001     1325
#
#                                              geometry            nom_mun  \
# 0   POLYGON ((2328998.333 938286.411, 2328992.454 ...  Acatl�n de Ju�rez
# 1   POLYGON ((2329856.497 937938.359, 2329843.636 ...  Acatl�n de Ju�rez
# 2   POLYGON ((2330222.579 938052.526, 2330204.500 ...                  0
# 3   POLYGON ((2329372.664 937326.401, 2329230.982 ...  Acatl�n de Ju�rez
# 4   POLYGON ((2328663.851 938014.271, 2328701.766 ...  Acatl�n de Ju�rez
# 5   POLYGON ((2329757.289 937226.525, 2329780.028 ...                  0
# 6   POLYGON ((2329751.218 937234.063, 2329741.868 ...  Acatl�n de Ju�rez
# 7   POLYGON ((2328715.082 938542.198, 2328745.425 ...  Acatl�n de Ju�rez
# 8   POLYGON ((2329632.518 937215.672, 2329642.410 ...                  0
# 9   POLYGON ((2329478.421 936997.567, 2329466.579 ...  Acatl�n de Ju�rez
# 10  POLYGON ((2329562.766 937004.735, 2329555.889 ...  Acatl�n de Ju�rez
# 11  POLYGON ((2330284.971 937931.529, 2330300.852 ...  Acatl�n de Ju�rez
# 12  POLYGON ((2328674.308 937938.338, 2328696.881 ...                  0
# 13  POLYGON ((2328685.910 938036.740, 2328663.851 ...                  0
# 14  POLYGON ((2330063.527 937174.626, 2330091.007 ...  Acatl�n de Ju�rez
# 15  POLYGON ((2329109.661 938217.440, 2329181.253 ...  Acatl�n de Ju�rez
# 16  POLYGON ((2333891.451 935360.697, 2333909.933 ...                  0
# 17  POLYGON ((2335121.875 937099.226, 2335147.449 ...  Acatl�n de Ju�rez
# 18  POLYGON ((2335137.895 935874.006, 2335129.591 ...  Acatl�n de Ju�rez
# 19  POLYGON ((2335041.202 937131.618, 2335015.312 ...  Acatl�n de Ju�rez
# 20  POLYGON ((2333545.618 937094.537, 2333498.237 ...  Acatl�n de Ju�rez
# 21  POLYGON ((2335433.858 936001.276, 2335445.098 ...  Acatl�n de Ju�rez
# 22  POLYGON ((2334621.644 935400.958, 2334609.355 ...  Acatl�n de Ju�rez
# 23  POLYGON ((2333467.527 936565.906, 2333467.187 ...                  0
# 24  POLYGON ((2334803.893 934583.814, 2334750.092 ...                  0
# 25  POLYGON ((2333205.849 936903.620, 2333215.772 ...  Acatl�n de Ju�rez
# 26  POLYGON ((2333433.953 935988.527, 2333427.469 ...  Acatl�n de Ju�rez
# 27  POLYGON ((2333241.552 937191.010, 2333200.911 ...                  0
# 28  POLYGON ((2335239.285 935824.555, 2335278.526 ...                  0
# 29  POLYGON ((2333200.911 937199.115, 2333241.552 ...                  0
# 30  POLYGON ((2335534.820 936248.012, 2335466.726 ...  Acatl�n de Ju�rez
# 31  POLYGON ((2357150.791 959790.056, 2357114.481 ...        Guadalajara
# 32  POLYGON ((2367389.408 966302.223, 2367366.228 ...        Guadalajara
# 33  POLYGON ((2363811.145 968828.465, 2363848.423 ...        Guadalajara
# 34  POLYGON ((2367420.611 966341.257, 2367273.896 ...        Guadalajara
# 35  POLYGON ((2368089.648 964164.191, 2368052.176 ...        Guadalajara
# 36  POLYGON ((2366581.336 962143.953, 2366700.508 ...        Guadalajara
# 37  POLYGON ((2361630.043 962476.234, 2361629.212 ...        Guadalajara
# 38  POLYGON ((2364167.127 968355.931, 2364172.475 ...        Guadalajara
# 39  POLYGON ((2365518.450 966007.163, 2365524.028 ...        Guadalajara
# 40  POLYGON ((2365133.519 964621.515, 2365040.324 ...        Guadalajara
# 41  POLYGON ((2358161.316 961045.647, 2358143.729 ...        Guadalajara
# 42  POLYGON ((2358721.889 961463.878, 2358717.259 ...        Guadalajara
# 43  POLYGON ((2358103.415 959121.736, 2358073.432 ...        Guadalajara
# 44  POLYGON ((2365360.343 961698.680, 2365359.317 ...        Guadalajara
# 45  POLYGON ((2358964.248 963828.876, 2358863.402 ...        Guadalajara
# 46  POLYGON ((2366143.019 960665.326, 2366062.546 ...        Guadalajara
# 47  POLYGON ((2358663.374 963265.851, 2358677.724 ...        Guadalajara
# 48  POLYGON ((2364686.270 962954.726, 2364702.436 ...        Guadalajara
# 49  POLYGON ((2358267.004 964307.823, 2358402.036 ...        Guadalajara
#
#    Rango_Pobreza  Pobreza_AV
# 0       (50, 70]        60.0
# 1       (18, 34]        26.0
# 2              0         0.0
# 3       (34, 50]        42.0
# 4       (34, 50]        42.0
# 5              0         0.0
# 6       (50, 70]        60.0
# 7      (70, 100]        85.0
# 8              0         0.0
# 9       (50, 70]        60.0
# 10      (50, 70]        60.0
# 11      (18, 34]        26.0
# 12             0         0.0
# 13             0         0.0
# 14      (34, 50]        42.0
# 15      (34, 50]        42.0
# 16             0         0.0
# 17      (18, 34]        26.0
# 18      (34, 50]        42.0
# 19      (18, 34]        26.0
# 20      (18, 34]        26.0
# 21      (18, 34]        26.0
# 22      (34, 50]        42.0
# 23             0         0.0
# 24             0         0.0
# 25      (34, 50]        42.0
# 26      (18, 34]        26.0
# 27             0         0.0
# 28             0         0.0
# 29             0         0.0
# 30      [ 0, 18]         0.0
# 31      [ 0, 18]         0.0
# 32      (34, 50]        42.0
# 33      (34, 50]        42.0
# 34      (34, 50]        42.0
# 35      (18, 34]        26.0
# 36      (34, 50]        42.0
# 37      (18, 34]        26.0
# 38      (18, 34]        26.0
# 39      (34, 50]        42.0
# 40      [ 0, 18]         0.0
# 41      (18, 34]        26.0
# 42      [ 0, 18]         0.0
# 43      (18, 34]        26.0
# 44      (18, 34]        26.0
# 45      (18, 34]        26.0
# 46      [ 0, 18]         0.0
# 47      [ 0, 18]         0.0
# 48      (34, 50]        42.0
# 49      [ 0, 18]         0.0

# %%
Pobreza_AGEB = Pobreza_AGEB.dropna()
Pobreza_AGEB.head()
print(Pobreza_A.shape)
# Out:
# (2068, 9)

# %%
Pobreza_A.crs
# Out:
# <Projected CRS: EPSG:6372>
# Name: Mexico ITRF2008 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
Pobreza_A=Pobreza_A.to_crs(epsg=3857)

# %%
mapclassify.NaturalBreaks(Pobreza_A['Pobreza_AV'].values, k=5)
# Out:
# NaturalBreaks
#
#    Interval      Count
# ----------------------
# [ 0.00,  0.00] |   927
# ( 0.00, 26.00] |   454
# (26.00, 42.00] |   420
# (42.00, 60.00] |   233
# (60.00, 85.00] |    34

# %% [markdown]
# ##**Mapa de pobreza por agebs**

# %%
fig, ax = plt.subplots(figsize=(14, 16))
style = "dark_all"
cartodb_url = 'https://a.basemaps.cartocdn.com/%s/{z}/{x}/{y}.png' % style
Base = Pobreza_A.plot(column='Pobreza_AV', 
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='summer',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
plt.title("Rango de pobreza en GDL(%)")
ax.set_axis_off() 
ctx.add_basemap(ax, alpha=0.9, url=cartodb_url)
plt.show()
# Out:
# <ipython-input-21-aafc3b2fd3e2>:14: FutureWarning: The "url" option is deprecated. Please use the "source" argument instead.
#   ctx.add_basemap(ax, alpha=0.9, url=cartodb_url)

# %%
Pobreza_AGEB=Pobreza_AGEB.to_crs(epsg=3857)

# %% [markdown]
# ##**Mapa de pobreza con agebs de 2015**

# %%
fig, ax = plt.subplots(figsize=(14, 16))
style = "dark_all"
cartodb_url = 'https://a.basemaps.cartocdn.com/%s/{z}/{x}/{y}.png' % style
Base = Pobreza_AGEB.plot(column='Pobreza_AV', 
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='summer',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
plt.title("Rango de pobreza en Guadalajara (%) agebs 2015")
ax.set_axis_off() 
ctx.add_basemap(ax, alpha=0.9, url=cartodb_url) 
plt.show()
# Out:
# <ipython-input-23-c774512aec98>:14: FutureWarning: The "url" option is deprecated. Please use the "source" argument instead.
#   ctx.add_basemap(ax, alpha=0.9, url=cartodb_url)

# %% [markdown]
# Importar OSM, para comparar las áreas verdes INEGI v.s. OSM

# %%
# !pip install osmnx
import osmnx as osm
# Out:
# Requirement already satisfied: osmnx in /opt/anaconda3/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: Shapely>=1.7 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (1.7.1)
# Requirement already satisfied: matplotlib>=3.3 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (3.4.1)
# Requirement already satisfied: networkx>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (2.5.1)
# Requirement already satisfied: geopandas>=0.8 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (0.9.0+24.ga26bde2)
# Requirement already satisfied: requests>=2.25 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (2.25.1)
# Requirement already satisfied: pandas>=1.1 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (1.2.4)
# Requirement already satisfied: descartes>=1.1 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (1.1.0)
# Requirement already satisfied: pyproj>=2.6 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (3.0.1)
# Requirement already satisfied: Rtree>=0.9 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (0.9.4)
# Requirement already satisfied: numpy>=1.19 in /opt/anaconda3/lib/python3.8/site-packages (from osmnx) (1.20.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3->osmnx) (1.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3->osmnx) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3->osmnx) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3->osmnx) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.3->osmnx) (7.2.0)
# Requirement already satisfied: decorator<5,>=4.3 in /opt/anaconda3/lib/python3.8/site-packages (from networkx>=2.5->osmnx) (4.4.2)
# Requirement already satisfied: fiona>=1.8 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas>=0.8->osmnx) (1.8.19)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25->osmnx) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25->osmnx) (2020.6.20)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25->osmnx) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25->osmnx) (2.10)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.1->osmnx) (2020.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from Rtree>=0.9->osmnx) (49.2.0.post20200714)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.3->osmnx) (1.15.0)
# Requirement already satisfied: attrs>=17 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx) (19.3.0)
# Requirement already satisfied: click<8,>=4.0 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx) (7.1.2)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx) (0.7.1)
# Requirement already satisfied: munch in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx) (2.5.0)

# %% [markdown]
# ##**4. Descargar áreas verdes de OSM**

# %%
# !pip install git+git://github.com/geopandas/geopandas.git
# Out:
# Collecting git+git://github.com/geopandas/geopandas.git
#   Cloning git://github.com/geopandas/geopandas.git to /private/var/folders/1l/mvt17qx11j1d442l6bqddhvc0000gn/T/pip-req-build-rgrnamg7
#   Running command git clone -q git://github.com/geopandas/geopandas.git /private/var/folders/1l/mvt17qx11j1d442l6bqddhvc0000gn/T/pip-req-build-rgrnamg7
# Requirement already satisfied (use --upgrade to upgrade): geopandas==0.9.0+24.ga26bde2 from git+git://github.com/geopandas/geopandas.git in /opt/anaconda3/lib/python3.8/site-packages
# Requirement already satisfied: pandas>=0.24.0 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas==0.9.0+24.ga26bde2) (1.2.4)
# Requirement already satisfied: shapely>=1.6 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas==0.9.0+24.ga26bde2) (1.7.1)
# Requirement already satisfied: fiona>=1.8 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas==0.9.0+24.ga26bde2) (1.8.19)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from geopandas==0.9.0+24.ga26bde2) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas==0.9.0+24.ga26bde2) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas==0.9.0+24.ga26bde2) (2020.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->geopandas==0.9.0+24.ga26bde2) (1.20.2)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (1.1.1)
# Requirement already satisfied: six>=1.7 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (1.15.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (2020.6.20)
# Requirement already satisfied: click<8,>=4.0 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (0.7.1)
# Requirement already satisfied: munch in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (2.5.0)
# Requirement already satisfied: attrs>=17 in /opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas==0.9.0+24.ga26bde2) (19.3.0)
# Building wheels for collected packages: geopandas
#   Building wheel for geopandas (setup.py) ... done
#   Created wheel for geopandas: filename=geopandas-0.9.0+24.ga26bde2-py2.py3-none-any.whl size=995295 sha256=e2cee6c00378a479f42e0ecc58d57a52a20b8466aada1088ad4c5b839329a5b1
#   Stored in directory: /private/var/folders/1l/mvt17qx11j1d442l6bqddhvc0000gn/T/pip-ephem-wheel-cache-c58nmlnz/wheels/37/ce/df/09721a3e578b57e217d038d0555fd872eba4e1fd9c8f6c8013
# Successfully built geopandas

# %% [markdown]
# ##**Todas las áreas verdes (sin discriminar a solamente parques)**

# %%
tags = {'leisure': True}
AreaV = osm.geometries_from_bbox(21.4863,19.8701, -102.7812, -103.8908, tags)

# %% [markdown]
# ##**Solamente parques**

# %%
Parque= AreaV.drop(AreaV[AreaV['leisure']!='park'].index)

# %%
Parque.set_index('osmid')
# Out:
#                   unique_id element_type leisure                  name  \
# osmid
# 2552012853  node/2552012853         node    park       plaza municipal
# 6492709075  node/6492709075         node    park         Lienzo Charro
# 248412445     way/248412445          way    park       plaza municipal
# 444469270     way/444469270          way    park    cancha la estacion
# 444469271     way/444469271          way    park  cancha 2 la estacion
# ...                     ...          ...     ...                   ...
# 747151349     way/747151349          way    park                   NaN
# 747151350     way/747151350          way    park       Plaza Santa Ana
# 752839950     way/752839950          way    park    Campo de Santa Ana
# 840266956     way/840266956          way    park                   NaN
# 840266959     way/840266959          way    park                   NaN
#
#                                                      geometry source  \
# osmid
# 2552012853                        POINT (-103.86195 20.08974)    NaN
# 6492709075                        POINT (-103.86166 20.08434)    OSM
# 248412445   POLYGON ((-103.86216 20.08960, -103.86208 20.0...    NaN
# 444469270   POLYGON ((-103.56897 20.23401, -103.56814 20.2...   Bing
# 444469271   POLYGON ((-103.57018 20.23452, -103.56926 20.2...   Bing
# ...                                                       ...    ...
# 747151349   POLYGON ((-103.04831 20.15906, -103.04844 20.1...    NaN
# 747151350   POLYGON ((-103.03780 20.15828, -103.03736 20.1...    NaN
# 752839950   POLYGON ((-103.03845 20.15954, -103.03916 20.1...    NaN
# 840266956   POLYGON ((-103.02711 19.97862, -103.02675 19.9...    NaN
# 840266959   POLYGON ((-103.02706 19.97995, -103.02669 19.9...    NaN
#
#                                                         nodes sport access  \
# osmid
# 2552012853                                                NaN   NaN    NaN
# 6492709075                                                NaN   NaN    NaN
# 248412445   [2552012854, 2552012855, 2552012856, 255201285...   NaN    NaN
# 444469270   [4419491452, 4419491449, 4419491445, 441949144...   NaN    NaN
# 444469271   [4419491455, 4419491453, 4419491448, 441949145...   NaN    NaN
# ...                                                       ...   ...    ...
# 747151349   [6991109797, 6991109798, 6991109799, 699110980...   NaN    NaN
# 747151350   [6991109801, 6991109802, 6991109803, 699110980...   NaN    NaN
# 752839950   [7034543161, 7034543162, 7034543163, 703454316...   NaN    NaN
# 840266956   [4363491668, 6603682927, 7892253481, 436349154...   NaN    NaN
# 840266959   [4363491549, 4363478376, 4363478374, 436349154...   NaN    NaN
#
#            surface  ... cycling addr:full water blind playground:theme  \
# osmid               ...
# 2552012853     NaN  ...     NaN       NaN   NaN   NaN              NaN
# 6492709075     NaN  ...     NaN       NaN   NaN   NaN              NaN
# 248412445      NaN  ...     NaN       NaN   NaN   NaN              NaN
# 444469270      NaN  ...     NaN       NaN   NaN   NaN              NaN
# 444469271      NaN  ...     NaN       NaN   NaN   NaN              NaN
# ...            ...  ...     ...       ...   ...   ...              ...
# 747151349      NaN  ...     NaN       NaN   NaN   NaN              NaN
# 747151350      NaN  ...     NaN       NaN   NaN   NaN              NaN
# 752839950      NaN  ...     NaN       NaN   NaN   NaN              NaN
# 840266956      NaN  ...     NaN       NaN   NaN   NaN              NaN
# 840266959      NaN  ...     NaN       NaN   NaN   NaN              NaN
#
#            bicycle foot horse motor_vehicle operator:type
# osmid
# 2552012853     NaN  NaN   NaN           NaN           NaN
# 6492709075     NaN  NaN   NaN           NaN           NaN
# 248412445      NaN  NaN   NaN           NaN           NaN
# 444469270      NaN  NaN   NaN           NaN           NaN
# 444469271      NaN  NaN   NaN           NaN           NaN
# ...            ...  ...   ...           ...           ...
# 747151349      NaN  NaN   NaN           NaN           NaN
# 747151350      NaN  NaN   NaN           NaN           NaN
# 752839950      NaN  NaN   NaN           NaN           NaN
# 840266956      NaN  NaN   NaN           NaN           NaN
# 840266959      NaN  NaN   NaN           NaN           NaN
#
# [1789 rows x 104 columns]

# %%
Parque.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
Parque=Parque.to_crs(epsg=6372)
Parque.head()
# Out:
#           unique_id       osmid element_type leisure                  name  \
# 1   node/2552012853  2552012853         node    park       plaza municipal
# 2   node/6492709075  6492709075         node    park         Lienzo Charro
# 3     way/248412445   248412445          way    park       plaza municipal
# 9     way/444469270   444469270          way    park    cancha la estacion
# 10    way/444469271   444469271          way    park  cancha 2 la estacion
#
#                                              geometry source  \
# 1                      POINT (2305981.395 899822.842)    NaN
# 2                      POINT (2306004.021 899227.262)    OSM
# 3   POLYGON ((2305959.328 899807.972, 2305968.678 ...    NaN
# 9   POLYGON ((2336682.801 915368.731, 2336769.154 ...   Bing
# 10  POLYGON ((2336557.506 915426.727, 2336652.808 ...   Bing
#
#                                                 nodes sport access  ...  \
# 1                                                 NaN   NaN    NaN  ...
# 2                                                 NaN   NaN    NaN  ...
# 3   [2552012854, 2552012855, 2552012856, 255201285...   NaN    NaN  ...
# 9   [4419491452, 4419491449, 4419491445, 441949144...   NaN    NaN  ...
# 10  [4419491455, 4419491453, 4419491448, 441949145...   NaN    NaN  ...
#
#    cycling addr:full water blind playground:theme bicycle foot horse  \
# 1      NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
# 2      NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
# 3      NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
# 9      NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
# 10     NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
#
#    motor_vehicle operator:type
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 9            NaN           NaN
# 10           NaN           NaN
#
# [5 rows x 105 columns]

# %% [markdown]
# ##**Parques de INEGI**

# %%
colors = ['#A1E2E6', '#E6BDA1', '#B3A16B', '#678072', '#524A4A']

# %%
Parques_Toluca= AGEBS.plot(color= colors[2], alpha=.2, figsize=(8,15))
Area_Verde.plot(ax=Parques_Toluca, color= '#039e7d',linewidth= 1.5)
plt.title("Zona metropolitana de Guadalajara \n con las Áreas verdes de INEGI", fontsize=20, color= '#03989e')
plt.axis('off')
plt.show()

# %% [markdown]
# ##**Parques OSM**

# %%
Parques_Tol_OSM= AGEBS.plot(color=colors[3], alpha=0.2, figsize=(8,16))
Parque.plot(ax=Parques_Tol_OSM, color= '#039e7d')
plt.title("Zona metropolitana de Guadalajara \n y Áreas verdes OSM", fontsize=20, color= '#03989e')
plt.axis('off')
plt.show()

# %%
Parque.crs
# Out:
# <Projected CRS: EPSG:6372>
# Name: Mexico ITRF2008 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
AGEBS.crs
# Out:
# <Projected CRS: EPSG:6372>
# Name: Mexico ITRF2008 / LCC
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Coordinate Operation:
# - name: Mexico LCC
# - method: Lambert Conic Conformal (2SP)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
Parque_Clip = gpd.clip(Parque, AGEBS)
Parque_Clip.head()
# Out:
#          unique_id      osmid element_type leisure  \
# 76   way/429181823  429181823          way    park
# 123  way/900149806  900149806          way    park
# 147  way/466225603  466225603          way    park
# 162  way/466282361  466282361          way    park
# 174  way/829874164  829874164          way    park
#
#                                      name  \
# 76                  Club Deportivo Juarez
# 123  Plaza Municipal de Acatlán de Juárez
# 147   Plaza Principal Venta del Astillero
# 162                        Plaza Nextipac
# 174                   Terraza Coto Albano
#
#                                               geometry source  \
# 76   POLYGON ((2334327.494 936212.332, 2334402.902 ...    NaN
# 123  POLYGON ((2334538.428 936160.707, 2334566.302 ...    NaN
# 147  POLYGON ((2339790.949 969862.243, 2339830.442 ...    NaN
# 162  POLYGON ((2341719.883 974088.225, 2341725.974 ...    NaN
# 174  POLYGON ((2339692.998 970917.952, 2339728.083 ...    NaN
#
#                                                  nodes sport access  ...  \
# 76   [4283089603, 4283089604, 4283089605, 428308960...   NaN    NaN  ...
# 123  [8362609885, 8362609886, 8362609887, 836260988...   NaN    NaN  ...
# 147  [4610843248, 4610843249, 4610843250, 461084326...   NaN    NaN  ...
# 162  [8410595815, 8410598817, 8410598819, 841059881...   NaN    NaN  ...
# 174  [7745459036, 6304257783, 6304258287, 774545903...   NaN    NaN  ...
#
#     cycling addr:full water blind playground:theme bicycle foot horse  \
# 76      NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
# 123     NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
# 147     NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
# 162     NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
# 174     NaN       NaN   NaN   NaN              NaN     NaN  NaN   NaN
#
#     motor_vehicle operator:type
# 76            NaN           NaN
# 123           NaN           NaN
# 147           NaN           NaN
# 162           NaN           NaN
# 174           NaN           NaN
#
# [5 rows x 105 columns]

# %% [markdown]
# ##**Parques OSM, solamente de la zona metropolitana**

# %%
Parques_Tol_OSM2= AGEBS.plot(color=colors[2], alpha=0.2, figsize=(8,8))
Parque_Clip.plot(ax=Parques_Tol_OSM2, color='#039e7d')
plt.title("Zona metropolitana de Guadalajara \n y Áreas verdes OSM", fontsize=20, color= '#03989e')
plt.axis('off')
plt.show()

# %%
AreaV.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
AreaV_INEGI=Area_Verde.to_crs(epsg=3857)
AreaV_OSM=Parque_Clip.to_crs(epsg=3857)

# %% [markdown]
# ## **Pobreza por ageb (Coneval, 2015)**

# %% [markdown]
# Parques Inegi y agebs clasificados por rango de pobreza

# %%
fig, ax = plt.subplots(figsize=(14, 16))
style = "dark_all"
cartodb_url = 'https://a.basemaps.cartocdn.com/%s/{z}/{x}/{y}.png' % style
Base = Pobreza_A.plot(column='Pobreza_AV',  
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='YlOrRd',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
AreaV_INEGI.plot(ax=Base, color='#039e7d')
plt.title("Rango de pobreza en Guadalajara (%) \n y Áreas Verdes INEGI", fontsize=20, color = '#03989e')
ax.set_axis_off() 
ctx.add_basemap(ax, alpha=0.9, url=cartodb_url) 
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# <ipython-input-40-0b25002aaa4a>:15: FutureWarning: The "url" option is deprecated. Please use the "source" argument instead.
#   ctx.add_basemap(ax, alpha=0.9, url=cartodb_url)

# %% [markdown]
# ##**Parques Inegi y agebs 2015 clasificados por rango de pobreza**

# %%
fig, ax = plt.subplots(figsize=(14, 16))
style = "dark_all"
cartodb_url = 'https://a.basemaps.cartocdn.com/%s/{z}/{x}/{y}.png' % style
Base = Pobreza_AGEB.plot(column='Pobreza_AV',  
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='YlOrRd',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
AreaV_INEGI.plot(ax=Base, color='#039e7d')
plt.title("Rango de pobreza en Guadalajara (%) \n y Áreas Verdes INEGI", fontsize=20, color = '#03989e')
ax.set_axis_off() 
ctx.add_basemap(ax, alpha=0.9, url=cartodb_url) 
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# <ipython-input-41-06f4cfc8fb8e>:15: FutureWarning: The "url" option is deprecated. Please use the "source" argument instead.
#   ctx.add_basemap(ax, alpha=0.9, url=cartodb_url)

# %% [markdown]
# #**Parques OSM y agebs clasificados por rango de pobreza**

# %%
fig, ax = plt.subplots(figsize=(14, 16))
style = "dark_all"
cartodb_url = 'https://a.basemaps.cartocdn.com/%s/{z}/{x}/{y}.png' % style
Base = Pobreza_A.plot(column='Pobreza_AV',  
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='YlOrRd',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
AreaV_OSM.plot(ax=Base, color='#039e7d')
plt.title("Rango de pobreza en Guadalajara (%) \n y Áreas Verdes OpenStreetMap", fontsize=20, color = '#03989e')
ax.set_axis_off() 
ctx.add_basemap(ax, alpha=0.9, url=cartodb_url) 
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# <ipython-input-42-51762cd94b8d>:15: FutureWarning: The "url" option is deprecated. Please use the "source" argument instead.
#   ctx.add_basemap(ax, alpha=0.9, url=cartodb_url)

# %% [markdown]
# ##**Parques OSM y agebs 2015 clasificados por rango de pobreza**

# %%
fig, ax = plt.subplots(figsize=(14, 16))
style = "dark_all"
cartodb_url = 'https://a.basemaps.cartocdn.com/%s/{z}/{x}/{y}.png' % style
Base = Pobreza_AGEB.plot(column='Pobreza_AV',  
              alpha=1, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='YlOrRd',
              classification_kwds={'k':5},
              figsize=(8,8),
              ax=ax)
AreaV_OSM.plot(ax=Base, color='#039e7d')
plt.title("Rango de pobreza en Guadalajara (%) \n y Áreas Verdes OpenStreetMap", fontsize=20, color = '#03989e')
ax.set_axis_off() 
ctx.add_basemap(ax, alpha=0.9, url=cartodb_url) 
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# <ipython-input-43-4ad5d3959844>:15: FutureWarning: The "url" option is deprecated. Please use the "source" argument instead.
#   ctx.add_basemap(ax, alpha=0.9, url=cartodb_url)

# %% [markdown]
# #**5. Cálculo de centroides de Agebs, Áreas Verdes de INEGI y Áreas Verdes de OSM**

# %%
import warnings
import numpy as np
import pandas as pd

from sklearn.metrics.pairwise import euclidean_distances

# %%
# !pip install access
from access import Access, weights, Datasets
# Out:
# Requirement already satisfied: access in /opt/anaconda3/lib/python3.8/site-packages (1.1.3)
# Requirement already satisfied: pandas>=0.23.4 in /opt/anaconda3/lib/python3.8/site-packages (from access) (1.2.4)
# Requirement already satisfied: numpy>=1.3 in /opt/anaconda3/lib/python3.8/site-packages (from access) (1.20.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23.4->access) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23.4->access) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.23.4->access) (1.15.0)

# %%
Centroide_AGEB1 = Pobreza_A.copy()
Centroide_AGEB1 = Centroide_AGEB1.reset_index()
Centroide_AGEB1 = Centroide_AGEB1[['Clave_AGEB', 'geometry', 'Pobreza_AV']]
Centroide_AGEB1['geometry'] = Centroide_AGEB1.to_crs(6372).centroid
centroides = Centroide_AGEB1.to_crs(6372).centroid
coordenadas = np.array([(pt.x , pt.y) for pt in centroides])
Centroide_AGEB1['X_O']=coordenadas[:,0]/1000
Centroide_AGEB1['Y_O']=coordenadas[:,1]/1000
Centroide_AGEB1.head(2)
# Out:
#       Clave_AGEB                        geometry  Pobreza_AV          X_O  \
# 0  1400200020219  POINT (2328857.591 938228.850)        60.0  2328.857591
# 1  1400200020045  POINT (2329726.805 937707.587)        26.0  2329.726805
#
#           Y_O
# 0  938.228850
# 1  937.707587

# %%
AGEBS_centro= AGEBS.plot(color=colors[2], alpha=0.2, figsize=(8,8))
Centroide_AGEB1.plot(ax=AGEBS_centro, color='#039e7d')
plt.title("Centroides de AGEBS (todas)", fontsize=20, color= '#03989e')
plt.axis('off')
plt.show()

# %%
Centroide_AGEB = Pobreza_AGEB.copy()
Centroide_AGEB = Centroide_AGEB.reset_index()
Centroide_AGEB = Centroide_AGEB[['Clave_AGEB', 'geometry', 'Pobreza_AV']]
Centroide_AGEB['geometry'] = Centroide_AGEB.to_crs(6372).centroid
centroides = Centroide_AGEB.to_crs(6372).centroid
coordenadas = np.array([(pt.x , pt.y) for pt in centroides])
Centroide_AGEB['X_O']=coordenadas[:,0]/1000
Centroide_AGEB['Y_O']=coordenadas[:,1]/1000
Centroide_AGEB.head(2)
# Out:
#       Clave_AGEB                        geometry  Pobreza_AV          X_O  \
# 0  1400200020219  POINT (2328857.591 938228.850)        60.0  2328.857591
# 1  1400200020045  POINT (2329726.805 937707.587)        26.0  2329.726805
#
#           Y_O
# 0  938.228850
# 1  937.707587

# %%
AGEBS_centro= AGEBS.plot(color=colors[2], alpha=0.2, figsize=(8,8))
Centroide_AGEB.plot(ax=AGEBS_centro, color='#039e7d')
plt.title("Centroides de AGEBS (2015)", fontsize=20, color= '#03989e')
plt.axis('off')
plt.show()

# %%
Centro_Area_Inegi = AreaV_INEGI.copy()
Centro_Area_Inegi = Centro_Area_Inegi.reset_index()
Centro_Area_Inegi = Centro_Area_Inegi[['CVEGEO', 'geometry', 'TIPO']]
Centro_Area_Inegi['geometry'] = Centro_Area_Inegi.to_crs(6372).centroid
centroides = Centro_Area_Inegi.to_crs(6372).centroid
coordenadas = np.array([(pt.x , pt.y) for pt in centroides])
Centro_Area_Inegi['X_D']=coordenadas[:,0]/1000
Centro_Area_Inegi['Y_D']=coordenadas[:,1]/1000
Centro_Area_Inegi.head(2)
# Out:
#       CVEGEO                        geometry        TIPO          X_D  \
# 0  140020002  POINT (2329110.929 937942.717)  Área Verde  2329.110929
# 1  140020004  POINT (2332736.349 936227.753)  Área Verde  2332.736349
#
#           Y_D
# 0  937.942717
# 1  936.227753

# %%
INEGI_centro= AGEBS.plot(color=colors[2], alpha=0.2, figsize=(8,8))
Centro_Area_Inegi.plot(ax=INEGI_centro, color='#039e7d')
plt.title("Centroides de parques INEGI", fontsize=20, color= '#03989e')
plt.axis('off')
plt.show()

# %%
OSM_Ce = AreaV_OSM.copy()
OSM_Ce['geometry'] = OSM_Ce.to_crs(6372).centroid
centroides = OSM_Ce.to_crs(6372).centroid
coordenadas = np.array([(pt.x , pt.y) for pt in centroides])
OSM_Ce['X_D']=coordenadas[:,0]/1000
OSM_Ce['Y_D']=coordenadas[:,1]/1000
OSM_Ce.head(2)
# Out:
#          unique_id      osmid element_type leisure  \
# 76   way/429181823  429181823          way    park
# 123  way/900149806  900149806          way    park
#
#                                      name                        geometry  \
# 76                  Club Deportivo Juarez  POINT (2334358.885 936153.019)
# 123  Plaza Municipal de Acatlán de Juárez  POINT (2334550.145 936119.250)
#
#     source                                              nodes sport access  \
# 76     NaN  [4283089603, 4283089604, 4283089605, 428308960...   NaN    NaN
# 123    NaN  [8362609885, 8362609886, 8362609887, 836260988...   NaN    NaN
#
#      ... water blind playground:theme bicycle foot horse motor_vehicle  \
# 76   ...   NaN   NaN              NaN     NaN  NaN   NaN           NaN
# 123  ...   NaN   NaN              NaN     NaN  NaN   NaN           NaN
#
#     operator:type          X_D         Y_D
# 76            NaN  2334.358885  936.153019
# 123           NaN  2334.550145  936.119250
#
# [2 rows x 107 columns]

# %%
OSM_Ce.set_index('osmid')
# Out:
#                unique_id element_type leisure  \
# osmid
# 429181823  way/429181823          way    park
# 900149806  way/900149806          way    park
# 466225603  way/466225603          way    park
# 466282361  way/466282361          way    park
# 829874164  way/829874164          way    park
# ...                  ...          ...     ...
# 639804827  way/639804827          way    park
# 639805325  way/639805325          way    park
# 639806668  way/639806668          way    park
# 753105991  way/753105991          way    park
# 753105992  way/753105992          way    park
#
#                                            name  \
# osmid
# 429181823                 Club Deportivo Juarez
# 900149806  Plaza Municipal de Acatlán de Juárez
# 466225603   Plaza Principal Venta del Astillero
# 466282361                        Plaza Nextipac
# 829874164                   Terraza Coto Albano
# ...                                         ...
# 639804827                         Parque Lineal
# 639805325                         Parque Lineal
# 639806668               Parque Lineal - Estadio
# 753105991                                   NaN
# 753105992                                   NaN
#
#                                  geometry source  \
# osmid
# 429181823  POINT (2334358.885 936153.019)    NaN
# 900149806  POINT (2334550.145 936119.250)    NaN
# 466225603  POINT (2339816.968 969839.372)    NaN
# 466282361  POINT (2341757.794 974118.897)    NaN
# 829874164  POINT (2339707.580 970893.368)    NaN
# ...                                   ...    ...
# 639804827  POINT (2388253.200 957567.850)    NaN
# 639805325  POINT (2388330.653 957649.127)    NaN
# 639806668  POINT (2388438.302 957228.035)    NaN
# 753105991  POINT (2388215.656 957370.189)    NaN
# 753105992  POINT (2388462.670 957251.443)    NaN
#
#                                                        nodes sport access  \
# osmid
# 429181823  [4283089603, 4283089604, 4283089605, 428308960...   NaN    NaN
# 900149806  [8362609885, 8362609886, 8362609887, 836260988...   NaN    NaN
# 466225603  [4610843248, 4610843249, 4610843250, 461084326...   NaN    NaN
# 466282361  [8410595815, 8410598817, 8410598819, 841059881...   NaN    NaN
# 829874164  [7745459036, 6304257783, 6304258287, 774545903...   NaN    NaN
# ...                                                      ...   ...    ...
# 639804827  [6028169394, 8377620953, 8377620952, 837762095...   NaN    NaN
# 639805325  [8377620954, 6028175148, 6028175149, 602817515...   NaN    NaN
# 639806668  [6028179664, 6028179665, 6028179666, 602817966...   NaN    NaN
# 753105991  [7036878308, 7036878309, 7036878310, 703687831...   NaN    NaN
# 753105992  [7036878326, 7036878327, 7036878328, 703687832...   NaN    NaN
#
#           surface  ... water blind playground:theme bicycle foot horse  \
# osmid              ...
# 429181823     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
# 900149806     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
# 466225603     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
# 466282361     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
# 829874164     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
# ...           ...  ...   ...   ...              ...     ...  ...   ...
# 639804827     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
# 639805325     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
# 639806668     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
# 753105991     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
# 753105992     NaN  ...   NaN   NaN              NaN     NaN  NaN   NaN
#
#           motor_vehicle operator:type          X_D         Y_D
# osmid
# 429181823           NaN           NaN  2334.358885  936.153019
# 900149806           NaN           NaN  2334.550145  936.119250
# 466225603           NaN           NaN  2339.816968  969.839372
# 466282361           NaN           NaN  2341.757794  974.118897
# 829874164           NaN           NaN  2339.707580  970.893368
# ...                 ...           ...          ...         ...
# 639804827           NaN           NaN  2388.253200  957.567850
# 639805325           NaN           NaN  2388.330653  957.649127
# 639806668           NaN           NaN  2388.438302  957.228035
# 753105991           NaN           NaN  2388.215656  957.370189
# 753105992           NaN           NaN  2388.462670  957.251443
#
# [1452 rows x 106 columns]

# %%
OSM_centro= AGEBS.plot(color=colors[2], alpha=0.2, figsize=(8,8))
OSM_Ce.plot(ax=OSM_centro, color='#039e7d')
plt.title("Centroides de parques OSM", fontsize=20, color= '#03989e')
plt.axis('off')
plt.show()

# %% [markdown]
# #**6. Cálculo de la distancia entre centroides de Agebs y centroides de áreas verdes (INEGI)**

# %%
dist_matrix = (euclidean_distances(Centroide_AGEB[['Y_O','X_O']], 
                              Centro_Area_Inegi[['Y_D','X_D']]))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:57: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float

# %%
df_dist_matrix = (pd.DataFrame(dist_matrix,index=Centroide_AGEB['Clave_AGEB'], 
                 columns=Centro_Area_Inegi['CVEGEO']))
df_dist_matrix.head(2)
# Out:
# CVEGEO         140020002  140020004  140020001  140020001  140020001  \
# Clave_AGEB
# 1400200020219   0.382167   4.364534   6.323438   6.428765   6.288860
# 1400200020045   0.659234   3.353694   5.310307   5.470542   5.335937
#
# CVEGEO         140020002  140020002  140020005  140020064  140390001  ...  \
# Clave_AGEB                                                            ...
# 1400200020219   0.537824   0.931293  12.831786   4.660836  47.194239  ...
# 1400200020045   0.678604   0.377891  11.873335   5.189583  46.766793  ...
#
# CVEGEO         141240196  141240196  141240196  141240196  141240127  \
# Clave_AGEB
# 1400200020219  80.216781  80.429152  80.523541  80.563947  81.073524
# 1400200020045  79.448560  79.659899  79.754004  79.794234  80.328116
#
# CVEGEO         141240127  141240127  141240051  141240051  141240051
# Clave_AGEB
# 1400200020219  81.107223  81.023685  65.529812  65.263563  65.314213
# 1400200020045  80.360913  80.276031  64.753600  64.489045  64.539643
#
# [2 rows x 4181 columns]

# %%
df_dist_long = (pd.melt(df_dist_matrix.reset_index(),id_vars='Clave_AGEB'))
df_dist_long = df_dist_long.rename(columns={'value':'Distancia'})
Matriz_Dist_INEGI= df_dist_long.rename({'Clave_AGEB':'Origen','CVEGEO': 'Destino'}, axis=1)
Matriz_Dist_INEGI.head(2)
# Out:
#           Origen    Destino  Distancia
# 0  1400200020219  140020002   0.382167
# 1  1400200020045  140020002   0.659234

# %% [markdown]
# #**7. Cálculo de la accesibilidad a áreas verdes (INEGI) con el Modelo Gravitacional**

# %%
Spatial_Access_INEGI = Access(demand_df    = Centroide_AGEB, 
                              demand_index = 'Clave_AGEB', 
                              demand_value = 'Pobreza_AV',
                              supply_df    = Centro_Area_Inegi, 
                              supply_index = 'CVEGEO',
                              cost_df      = Matriz_Dist_INEGI, 
                              cost_origin  = 'Origen', 
                              cost_dest    = 'Destino',
                              cost_name    = 'Distancia')
# Out:
# access INFO     :: Warning: A supply value was not provided, so a default
#                              supply value of 1 was created in the column named "value".
#                              Note that without a supply value, you cannot use any of the
#                              floating catchment area methods.

# %%
Model_grav = weights.gravity(scale = 1, alpha = -2, min_dist = 0.5)

Gravity_Weigh = Spatial_Access_INEGI.weighted_catchment(name = "Gravity", weight_fn = Model_grav)

# %%
Grav_value = Gravity_Weigh.copy().reset_index()
Spatial_Access_I= Pobreza_AGEB.merge(Grav_value ,left_on='Clave_AGEB', right_on='Clave_AGEB',how='left')

# %%
Pobreza_AGEB=Pobreza_AGEB.to_crs(epsg = 3857)
Pobreza_A=Pobreza_A.to_crs(epsg = 3857)
AreaV_INEGI=AreaV_INEGI.to_crs(epsg = 3857)
Spatial_Access_I=Spatial_Access_I.to_crs(epsg = 3857)

# %%
Spatial_Access_I.head()

# %%
Spatial_Access_I.info()

# %%
Spatial_Access_I['Pobreza_AV']= Spatial_Access_I.Pobre_AV.astype(int)

# %%
Spatial_Access_I['Gravity_value']= Spatial_Access_I.Gravity_value.astype(int)

# %%
import datetime
from os import listdir
from os.path import isfile, join
import glob
import re
import seaborn as sns

# %% [markdown]
# ##**8. Estandarización de variables**

# %%
Spatial_Access_I['Std_Pobreza'] = (Spatial_Access_I['Pobreza_AV'] - Spatial_Access_I['Pobreza_AV'].mean()) / Spatial_Access_I['Pobreza_AV'].std()

# %%
Spatial_Access_I['Std_Access'] = (Spatial_Access_I['Gravity_value'] - Spatial_Access_I['Gravity_value'].mean()) / Spatial_Access_I['Gravity_value'].std()

# %% [markdown]
# ##**Diagramas para ver la relación entre la pobreza y la accesibilidad a áreas verdes (INEGI)**

# %%
h=sns.jointplot(data=Spatial_Access_I, x = Spatial_Access_I['Std_Pobreza'], y = Spatial_Access_I['Std_Access'],color = '#618A98', kind = 'reg')
h.fig.suptitle("Diagrama Pobreza-Accesibilidad", alpha = 0.5, fontsize=20, color='#03989e')
h.set_axis_labels('Pobreza por AGEB','Accesibilidad a áreas verdes',fontsize=15, alpha = 0.5, color='#03989e')
plt.axvline(0, c = 'grey', alpha = 0.5)
plt.axhline(0, c = 'grey', alpha = 0.5)
h.fig.subplots_adjust(top=0.90)
plt.show()

# %%
plt.subplots(1,figsize=(10,5))
ax= sns.regplot(data=Spatial_Access_I, x = Spatial_Access_I['Std_Pobreza'], y = Spatial_Access_I['Std_Access'],scatter_kws={"color": "#F9DA95"}, line_kws={"color": "#618A98"})
sns.set_style('ticks')
ax.axes.set_title("Scatter Pobreza-Accesibilidad", alpha = 0.5, fontsize=20, color='#03989e')
ax.set_xlabel("Pobreza",fontsize=15, alpha = 0.5, color='#03989e')
ax.set_ylabel("Accesibilidad \n a áreas verdes",fontsize=15, alpha = 0.5, color='#03989e')
plt.axvline(0, c = 'grey', alpha = 0.5)
plt.axhline(0, c = 'grey', alpha = 0.5)
plt.show()

# %%
fig , filas = plt.subplots(1,2, figsize=(50,15))
for ax in filas: 
    if (ax==filas[0]):
        sns.kdeplot(Spatial_Access_I['Std_Access'], shade = True, color= "#F9DA95", ax=ax)
    elif (ax==filas[1]):
        sns.kdeplot(Spatial_Access_I['Std_Pobreza'], shade = True, color= "#618A98", ax=ax)

# %% [markdown]
# ##**Mapa de accesibilidad a áreas verdes (INEGI)**

# %%
Base = Spatial_Access_I.plot(column='Std_Access', 
              alpha=0.8, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='viridis',
              classification_kwds={'k':5},
              figsize=(15,15))
AreaV_INEGI.plot(ax=Base, color='#00B464')
plt.title("Accesibilidad espacial \n áreas verdes INEGI", fontsize=20, color= '#03989e')
plt.axis('off')
plt.show()

# %% [markdown]
# #**9. Cálculo de la distancia entre centroides de Agebs y centroides de áreas verdes (OSM)**

# %%
dist_matrix2 = (euclidean_distances(Centroide_AGEB[['Y_O','X_O']], 
                              OSM_Ce[['Y_D','X_D']]))

# %%
df_dist_matrix2 = (pd.DataFrame(dist_matrix2,index=Centroide_AGEB['Clave_AGEB'], 
                 columns=OSM_Ce['osmid']))
df_dist_matrix2.head(2)

# %%
df_dist_long2 = (pd.melt(df_dist_matrix2.reset_index(),id_vars='Clave_AGEB'))
df_dist_long2 = df_dist_long2.rename(columns={'value':'Distancia'})
Matriz_Dist2= df_dist_long2.rename({'Clave_AGEB':'Origen','osmid': 'Destino'}, axis=1)
Matriz_Dist2.head(2)

# %% [markdown]
# #**10. Cálculo de la accesibilidad a áreas verdes (OSM) con el Modelo Gravitacional**

# %%
Spatial_Access_data2= Access(demand_df    = Centroide_AGEB, 
                              demand_index = 'Clave_AGEB', 
                              demand_value = 'Pobreza_AV',
                              supply_df    = OSM_Ce, 
                              supply_index = 'osmid',
                              cost_df      = Matriz_Dist2, 
                              cost_origin  = 'Origen', 
                              cost_dest    = 'Destino',
                              cost_name    = 'Distancia')

# %%
Model_grav2 = weights.gravity(scale = 1, alpha = -2, min_dist = 0.5)

Gravity_Weigh2 = Spatial_Access_data2.weighted_catchment(name = "Gravity", weight_fn = Model_grav2)

# %%
Grav_value2 = Gravity_Weigh2.copy().reset_index()
Spatial_Access2 = Pobreza_AGEB.merge(Grav_value2 ,left_on='Clave_AGEB', right_on='Clave_AGEB',how='left')

# %%
Spatial_Access2.head()

# %% [markdown]
# ##**Mapa de accesibilidad a áreas verdes (OSM)**

# %%
Base = Spatial_Access2.plot(column='Gravity_value', 
              alpha=0.8, 
              scheme='NaturalBreaks', 
              legend=True, 
              cmap='viridis',
              classification_kwds={'k':5},
              figsize=(15,15))
AreaV_OSM.plot(ax=Base, color='#00B464')
plt.title("Accesibilidad espacial \n áreas verdes OSM", fontsize=20, color= '#03989e')
plt.axis('off')
plt.show()

# %% [markdown]
# ##**11. Estandarización de variables**

# %%
Spatial_Access2['Std_Pobreza'] = (Spatial_Access2['Pobreza_AV'] - Spatial_Access2['Pobreza_AV'].mean()) / Spatial_Access2['Pobreza_AV'].std()

# %%
Spatial_Access2['Std_Access'] = (Spatial_Access2['Gravity_value'] - Spatial_Access2['Gravity_value'].mean()) / Spatial_Access2['Gravity_value'].std()

# %% [markdown]
# ##**Diagramas para ver la relación entre la pobreza y la accesibilidad a áreas verdes (OSM)**

# %%
h=sns.jointplot(data=Spatial_Access2, x = Spatial_Access2['Std_Pobreza'], y = Spatial_Access2['Std_Access'],color = '#618A98', kind = 'reg')
h.fig.suptitle("Diagrama Pobreza-Accesibilidad", alpha = 0.5, fontsize=20, color='#03989e')
h.set_axis_labels('Pobreza por AGEB','Accesibilidad a áreas verdes',fontsize=15, alpha = 0.5, color='#03989e')
plt.axvline(0, c = 'grey', alpha = 0.5)
plt.axhline(0, c = 'grey', alpha = 0.5)
h.fig.subplots_adjust(top=0.90)
plt.show()

# %%
plt.subplots(1,figsize=(10,5))
ax= sns.regplot(data=Spatial_Access2, x = Spatial_Access2['Std_Pobreza'], y = Spatial_Access2['Std_Access'],scatter_kws={"color": "#F9DA95"}, line_kws={"color": "#618A98"})
sns.set_style('ticks')
ax.axes.set_title("Scatter Pobreza-Accesibilidad", alpha = 0.5, fontsize=20, color='#03989e')
ax.set_xlabel("Pobreza",fontsize=15, alpha = 0.5, color='#03989e')
ax.set_ylabel("Accesibilidad \n a áreas verdes",fontsize=15, alpha = 0.5, color='#03989e')
plt.axvline(0, c = 'grey', alpha = 0.5)
plt.axhline(0, c = 'grey', alpha = 0.5)
plt.show()

# %%
fig , filas = plt.subplots(1,2, figsize=(50,15))
for ax in filas: 
    if (ax==filas[0]):
        sns.kdeplot(Spatial_Access2['Std_Access'], shade = True, color= "#F9DA95", ax=ax)
    elif (ax==filas[1]):
        sns.kdeplot(Spatial_Access2['Std_Pobreza'], shade = True, color= "#618A98", ax=ax)

# %%
# !pip install folium
import folium

# %%
Spatial_Access2.to_file("Spatial_Access2.geojson", driver='GeoJSON')

# %%
OSM_Ce = pd.DataFrame(OSM_Ce)

# %%
Spatial_Access_I.to_file("Spatial_Access_I.geojson", driver='GeoJSON')

# %%
OSM_Ce.to_file("OSM_Ce.geojson", driver='GeoJSON')

# %%
from folium import Choropleth

# %% [markdown]
# ##**Mapa de accesibilidad y pobreza, con áreas verdes (INEGI)**

# %%
#popup=Popup('Portland, OR'))
m = folium.Map([20.667818 , -103.368437], zoom_start=10, tiles=None)
folium.TileLayer('CartoDB positron',name="Light Map",control=False).add_to(m)
folium.Choropleth(
    geo_data=AGEBS,
    data=Spatial_Access_I,
    name="Pobreza",
    columns=["Clave_AGEB", "Pobreza_AV"],
    key_on="feature.properties.Clave_AGEB",
    scheme='NaturalBreaks',
    fill_color="YlOrRd",
    fill_opacity=1,
    line_opacity=0.5,
    legend_name="Pobreza (%)",
    highlight=True,
    nan_fill_color = "lightgrey",
    line_color='red' 
).add_to(m)
folium.Choropleth(
    geo_data=AGEBS,
    data=Spatial_Access_I,
    name="Accesibilidad",
    columns=["Clave_AGEB", "Std_Access"],
    key_on="feature.properties.Clave_AGEB",
    scheme='NaturalBreaks',
    fill_color="PuRd",
    fill_opacity=1,
    line_opacity=0.7,
    legend_name="Accesibilidad",
    highlight=True,
    nan_fill_color = "lightgrey",
    line_color='purple' 
).add_to(m)

folium.features.GeoJson(Area_Verde,
            name='Áreas Verdes',
           style_function=lambda feature :{'fillColor': 'green' if feature['properties']['Valor']==1 else '#008000',
        'color': 'green',
        'weight': 2,
        'dashArray': '5, 5'},show=True).add_to(m)
folium.LayerControl(collapsed=True).add_to(m)

m
